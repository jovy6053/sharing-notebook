# %% [markdown]
# # Applied Data Science Project

# %% [markdown]
# ### This notebook is intended for use in Applied Data Science Project

# %%
# Import Libraries
import pandas as pd
import numpy as np

print('Hello Capstone Project Course!')
# Out:
# Hello Capstone Project Course!
